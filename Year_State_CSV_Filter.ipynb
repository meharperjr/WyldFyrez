# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#requsting csv and reading
fire_csv = "Resources/fire_Final.csv"

df_fire = pd.read_csv(fire_csv, low_memory=False)

df_fire.head(10)
# Out:
#    OBJECTID STAT_CAUSE_DESCR STATE Date_Discovery Date_Contained  FIRE_YEAR  \
# 0         1    Miscellaneous    CA       2/2/2005       2/2/2005       2005
# 1         2        Lightning    CA      5/12/2004      5/12/2004       2004
# 2         3   Debris Burning    CA      5/31/2004      5/31/2004       2004
# 3         4        Lightning    CA      6/28/2004       7/3/2004       2004
# 4         5        Lightning    CA      6/28/2004       7/3/2004       2004
# 5         6        Lightning    CA      6/30/2004       7/1/2004       2004
# 6         7        Lightning    CA       7/1/2004       7/2/2004       2004
# 7         8   Debris Burning    CA       3/8/2005       3/8/2005       2005
# 8         9   Debris Burning    CA      3/15/2005      3/15/2005       2005
# 9        10        Lightning    CA       7/1/2004       7/2/2004       2004
#
#    FIRE_SIZE   LATITUDE   LONGITUDE  Duration
# 0       0.10  40.036944 -121.005833         0
# ...

# %%
fire_2015 = df_fire[df_fire.STATE == "GA" ]
fire_2015
# Out:
#         OBJECTID STAT_CAUSE_DESCR STATE Date_Discovery Date_Contained  \
# 4432        4448            Arson    GA      11/4/2005      11/4/2005
# 4436        4452            Arson    GA      11/4/2005      11/4/2005
# 4440        4456   Debris Burning    GA     11/12/2005     11/12/2005
# 4448        4464   Debris Burning    GA      11/3/2005      11/3/2005
# 4761        4778   Debris Burning    GA      3/12/2005      3/12/2005
# 4765        4782    Miscellaneous    GA      2/11/2005      2/11/2005
# 4770        4787    Miscellaneous    GA     11/10/2005     11/10/2005
# 4771        4788    Miscellaneous    GA      4/17/2005      4/17/2005
# 4772        4789            Arson    GA      3/12/2005      3/12/2005
# 4773        4790    Equipment Use    GA      7/17/2005      7/17/2005
# 4774        4791            Arson    GA      3/13/2005      3/13/2005
# 4780        4797         Campfire    GA       2/6/2005       2/6/2005
# ...

# %%
fire_2015_df= pd.DataFrame(fire_2015)

# %%
fire_2015_df.dtypes
# Out:
# OBJECTID              int64
# STAT_CAUSE_DESCR     object
# STATE                object
# Date_Discovery       object
# Date_Contained       object
# FIRE_YEAR             int64
# FIRE_SIZE           float64
# LATITUDE            float64
# LONGITUDE           float64
# Duration              int64
# dtype: object

# %%
fire_2015.to_csv("Resources/GAFireData.csv",index = False)
