# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#requsting csv and reading
firestart_csv = "Resources/fire_start.csv"

df_firestart = pd.read_csv(firestart_csv, low_memory=False, dtype={'FIRE_YEAR': int})

df_firestart.head()
# Out:
#             X          Y  OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE  \
# 0 -121.005847  40.036950         1       1  FS-1418826                FED
# 1 -120.404457  38.933061         2       2  FS-1418827                FED
# 2 -120.735569  38.984172         3       3  FS-1418835                FED
# 3 -119.913346  38.559172         4       4  FS-1418845                FED
# 4 -119.933068  38.559172         5       5  FS-1418847                FED
#
#   SOURCE_SYSTEM NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  \
# 0   FS-FIRESTAT                    FS                USCAPNF
# 1   FS-FIRESTAT                    FS                USCAENF
# 2   FS-FIRESTAT                    FS                USCAENF
# 3   FS-FIRESTAT                    FS                USCAENF
# 4   FS-FIRESTAT                    FS                USCAENF
#
#    NWCG_REPORTING_UNIT_NAME  ... FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE  \
# 0    Plumas National Forest  ...      0.10               A  40.036944
# ...

# %%
df_sub = df_firestart[['OBJECTID','STAT_CAUSE_DESCR', 'STATE','FIRE_YEAR', 'CONT_DATE', 'DISCOVERY_DATE', 'FIRE_SIZE', 'LATITUDE', 'LONGITUDE']]
df_sub.dtypes
# Out:
# OBJECTID              int64
# STAT_CAUSE_DESCR     object
# STATE                object
# FIRE_YEAR             int32
# CONT_DATE            object
# DISCOVERY_DATE       object
# FIRE_SIZE           float64
# LATITUDE            float64
# LONGITUDE           float64
# dtype: object

# %%
df_dropstart = df_sub.dropna(how="any")
df_dropstart.count()
# Out:
# OBJECTID            988934
# STAT_CAUSE_DESCR    988934
# STATE               988934
# FIRE_YEAR           988934
# CONT_DATE           988934
# DISCOVERY_DATE      988934
# FIRE_SIZE           988934
# LATITUDE            988934
# LONGITUDE           988934
# dtype: int64

# %%
df_dropstart.to_csv("Resources/fire_init.csv")
